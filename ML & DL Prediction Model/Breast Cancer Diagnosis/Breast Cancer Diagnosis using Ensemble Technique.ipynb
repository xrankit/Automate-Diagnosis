# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('breast-cancer-wisconsin.data')

# %%
df.head()
# Out:
#    1000025  5   1  1.1  1.2  2 1.3  3  1.4  1.5  2.1
# 0  1002945  5   4    4    5  7  10  3    2    1    2
# 1  1015425  3   1    1    1  2   2  3    1    1    2
# 2  1016277  6   8    8    1  3   4  3    7    1    2
# 3  1017023  4   1    1    3  2   1  3    1    1    2
# 4  1017122  8  10   10    8  7  10  9    7    1    4

# %%
df.columns = ['Id_number','Clump Thickness','Uniformity of Cell Size','Uniformity of Cell Shape','Marginal Adhesion','Single Epithelial Cell Size','Bare Nuclei','Bland Chromatin','Normal_Nucleoli','Mitoses','Class']

# %%
df
# Out:
#      Id_number  Clump Thickness  Uniformity of Cell Size  \
# 0      1002945                5                        4
# 1      1015425                3                        1
# 2      1016277                6                        8
# 3      1017023                4                        1
# 4      1017122                8                       10
# ..         ...              ...                      ...
# 693     776715                3                        1
# 694     841769                2                        1
# 695     888820                5                       10
# 696     897471                4                        8
# 697     897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           4                  5                            7
# 1                           1                  1                            2
# ...

# %%
df.head()
# Out:
#    Id_number  Clump Thickness  Uniformity of Cell Size  \
# 0    1002945                5                        4
# 1    1015425                3                        1
# 2    1016277                6                        8
# 3    1017023                4                        1
# 4    1017122                8                       10
#
#    Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                         4                  5                            7
# 1                         1                  1                            2
# 2                         8                  1                            3
# 3                         1                  3                            2
# 4                        10                  8                            7
#
#   Bare Nuclei  Bland Chromatin  Normal_Nucleoli  Mitoses  Class
# 0          10                3                2        1      2
# ...

# %%
df.drop(['Id_number'],axis = 1, inplace = True)

# %%
df.describe()
# Out:
#        Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# count       698.000000               698.000000                698.000000
# mean          4.416905                 3.137536                  3.210602
# std           2.817673                 3.052575                  2.972867
# min           1.000000                 1.000000                  1.000000
# 25%           2.000000                 1.000000                  1.000000
# 50%           4.000000                 1.000000                  1.000000
# 75%           6.000000                 5.000000                  5.000000
# max          10.000000                10.000000                 10.000000
#
#        Marginal Adhesion  Single Epithelial Cell Size  Bland Chromatin  \
# count         698.000000                   698.000000       698.000000
# mean            2.809456                     3.217765         3.438395
# std             2.856606                     2.215408         2.440056
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Clump Thickness              698 non-null    int64
#  1   Uniformity of Cell Size      698 non-null    int64
#  2   Uniformity of Cell Shape     698 non-null    int64
#  3   Marginal Adhesion            698 non-null    int64
#  4   Single Epithelial Cell Size  698 non-null    int64
#  5   Bare Nuclei                  698 non-null    object
#  6   Bland Chromatin              698 non-null    int64
#  7   Normal_Nucleoli              698 non-null    int64
#  8   Mitoses                      698 non-null    int64
#  9   Class                        698 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 54.7+ KB

# %%
missing_values_count = df.isnull().sum()

total_cells = np.product(df.shape)

total_missing = missing_values_count.sum()

percentage_missing = (total_missing/total_cells)*100
print(percentage_missing)
# Out:
# 0.0

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()
le.fit(df['Bare Nuclei'])
list(le.classes_)
df['Bare Nuclei'] = le.transform(df['Bare Nuclei']) 
df.head()
# Out:
#    Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                5                        4                         4
# 1                3                        1                         1
# 2                6                        8                         8
# 3                4                        1                         1
# 4                8                       10                        10
#
#    Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# 0                  5                            7            1
# 1                  1                            2            2
# 2                  1                            3            4
# 3                  3                            2            0
# 4                  8                            7            1
#
#    Bland Chromatin  Normal_Nucleoli  Mitoses  Class
# 0                3                2        1      2
# 1                3                1        1      2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Clump Thickness              698 non-null    int64
#  1   Uniformity of Cell Size      698 non-null    int64
#  2   Uniformity of Cell Shape     698 non-null    int64
#  3   Marginal Adhesion            698 non-null    int64
#  4   Single Epithelial Cell Size  698 non-null    int64
#  5   Bare Nuclei                  698 non-null    int64
#  6   Bland Chromatin              698 non-null    int64
#  7   Normal_Nucleoli              698 non-null    int64
#  8   Mitoses                      698 non-null    int64
#  9   Class                        698 non-null    int64
# dtypes: int64(10)
# memory usage: 54.7 KB
